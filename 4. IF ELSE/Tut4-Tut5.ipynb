# %% [markdown]
# # Tut 4

# %% [markdown]
# # Some more Operators

# %%
# greater than or equal to >=
a = 13
b =13

print(b>=a)
# Out:
# True

# %%
# less than or equalto <=
a = 14
b =14

print(a<=b)
# Out:
# True

# %%
# mod operator %
a= 97
b=7
print(a%b)
# Out:
# 6

# %%
a= 14
b=7
print(a%b)
print(b%a)
# Out:
# 0
# 7

# %% [markdown]
# # If else
# ![if%20else.jpg](attachment:if%20else.jpg)

# %%
number = int(input('Enter a number: '))
# to check if number is divisible by 17
if(number%17==0):
    print('Number is divisible by 17')
else:
    print('Number is not divisible by 17')
# Out:
# Enter a number: 1649
# Number is divisible by 17

# %%
age = int(input('Enter your age: '))

if(age>=18):
    print('You can vote')
else:
    print('You cannot vote, you are a kid now')
# Out:
# Enter your age: 14
# You cannot vote, you are a kid now

# %% [markdown]
# # Indentation

# %% [markdown]
# ![indentation.jpg](attachment:indentation.jpg)

# %%
age = int(input('Enter your age: '))

if(age>=18):
    print('You can vote')
    print('I am in if block')
else:
    print('You cannot vote, you are a kid now')
     print('I am in else block')
print('Code finished')
# Out:
#   Input In [25]
#     print('I am in else block')
#     ^
# IndentationError: unexpected indent

# %%
if a>b:
    # statement
else:
    # else statement
print ('code is finished ')

# %% [markdown]
# # Tut 5

# %% [markdown]
# # if else elif
# ![if%20else%20elif.jpg](attachment:if%20else%20elif.jpg)

# %%
age = int(input('Enter your age: '))

# checking condition one
if age>0 and age<=15:
    print('You are in School')
elif age>=16 and age<=22:
    print('You are in college')
elif age>=23:
    print('You are a working Professional')
else:
    print('Age input is invalid')
# Out:
# Enter your age: -20
# Age input is invalid

# %% [markdown]
# # Nested if else
# ![nested%20if%20else.jpg](attachment:nested%20if%20else.jpg)

# %%
number= int(input('Enter the number:'))

if number>=0:
    if number==0:
        print('number is zero')
    else:
        print('number is positive')
else:
    print('number is negative')
# Out:
# Enter the number:-5
# number is negative

# %% [markdown]
# # Exercise

# %%
# take three numbers as inputs and print the largest number 
a = float(input('Enter the number a: '))
b = float(input('Enter the number b: '))
c = float(input('Enter the number c: '))

#write your code here 

print('The largest number is {}'.fromat(ans))
